# %%
import cv2
import numpy as np

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

# %%
img = cv2.imread("img/sample1.jpg")

# %%
cv2.imshow("MY_IMAGE", img)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # EQUALIZE HISTOGRAM
# ```python
# cv2.equaliseHist(img_array)
# ```

# %%
# cv2.equalizeHist(img[:][:][::-1])

# %%
cv2.equalizeHist(cv2.cvtColor(img,cv2.COLOR_BGR2))
# Out:
# array([[ 25,  25,  25, ..., 118, 118, 118],
#        [ 25,  25,  25, ..., 116, 116, 116],
#        [ 25,  25,  25, ..., 116, 116, 116],
#        ...,
#        [ 36,  38,  40, ..., 116,  68,  95],
#        [ 34,  34,  35, ...,  80,  52, 128],
#        [ 27,  28,  28, ...,  50,  36, 103]], dtype=uint8)

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
plt.show()

# %%
num1 = np.uint8([24])
num2 = np.uint8([222])

# %%
cv2.add(num1,num2)
# Out:
# array([[246]], dtype=uint8)

# %%
num1
# Out:
# array([24], dtype=uint8)
